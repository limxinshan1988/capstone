# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv("C:\Users\dbsxsl\Desktop\Food_consumption_2008_2018_countries.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#   File "<ipython-input-2-49f6c507cc2c>", line 6
#     data = pd.read_csv("C:\Users\dbsxsl\Desktop\Food_consumption_2008_2018_countries.csv")
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 
# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
data = pd.read_csv(r"C:\Users\dbsxsl\Desktop\Food_consumption_2008_2018_countries.csv") 
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#                     Country  Year                          FoodCode FoodName  \
# 0  United States of America  2010  298638831e59722a35d3c6f2d76d9366      NaN
# 1  United States of America  2010  298638831e59722a35d3c6f2d76d9366      NaN
# 2  United States of America  2010  298638831e59722a35d3c6f2d76d9366      NaN
# 3  United States of America  2010  298638831e59722a35d3c6f2d76d9366      NaN
# 4  United States of America  2010  298638831e59722a35d3c6f2d76d9366      NaN
#
#                    AgeClass SourceAgeClass Gender  Number_of_consumers  \
# 0                       All            All    All                24289
# 1      Infants and Toddlers    0-35 months   male                 1184
# 2  Children and Adolescents      3-5 years   male                  732
# 3  Children and Adolescents     6-14 years   male                 2154
# 4        Adults and Elderly    15-49 years   male                 4414
#
#    Consumers_Mean  Consumers_Median  ...  \
# ...

# %%
# data1 = oringal data dataframe without NaN value  
data1 = data.dropna() 
data1.head()
# Out:
#                      Country  Year FoodCode         FoodName  \
# 21  United States of America  2010    A000M  Amaranth grains
# 22  United States of America  2010    A000M  Amaranth grains
# 23  United States of America  2010    A000M  Amaranth grains
# 24  United States of America  2010    A000M  Amaranth grains
# 25  United States of America  2010    A000M  Amaranth grains
#
#                     AgeClass SourceAgeClass Gender  Number_of_consumers  \
# 21                       All            All    All                   16
# 22      Infants and Toddlers    0-35 months   male                    0
# 23  Children and Adolescents      3-5 years   male                    0
# 24  Children and Adolescents     6-14 years   male                    1
# 25        Adults and Elderly    15-49 years   male                    4
#
#     Consumers_Mean  Consumers_Median  ...  \
# 21        0.002277          0.001429  ...
# 22        0.000000          0.000000  ...
# ...

# %%
data1.FoodName.unique()
# Out:
# array(['Amaranth grains', 'Buckwheat', 'Common millet grain', ...,
#        'Coconut milk powder', 'Juice concentrate, apple',
#        'Juice concentrate, pineapple'], dtype=object)

# %%
# data2 = full list of FoodName 
data2 = data1.FoodName.unique()

# %%
len(data2)
# Out:
# 1722

# %%
# data3 = data2 without Juice concentrate, apple
data3 = data2.drop(index='(Juice concentrate, apple)', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-ef5a88530424> in <module>
#       1 # data3 = data2 without Juice concentrate, apple
# ----> 2 data3 = data2.drop(index='(Juice concentrate, apple)', inplace=True)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'drop'

# %%
# data frame = data from food_comsumption_US
data_US = pd.read_csv(r"C:\Users\dbsxsl\Desktop\Food_consumption_USA.csv") 
# Preview the first 5 lines of the loaded data 
data_US.head()
# Out:
#                     Country  Year                          FoodCode  \
# 0  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 1  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 2  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 3  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 4  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
#
#        FoodName                  AgeClass SourceAgeClass Gender  \
# 0  (All Fruits)                       All            All    All
# 1  (All Fruits)      Infants and Toddlers    0-35 months   male
# 2  (All Fruits)  Children and Adolescents      3-5 years   male
# 3  (All Fruits)  Children and Adolescents     6-14 years   male
# 4  (All Fruits)        Adults and Elderly    15-49 years   male
#
#    Number_of_consumers  Consumers_Mean  Consumers_Median  ...  \
# 0                21206        2.399773          1.222423  ...
# ...

# %%
# data1 = oringal data dataframe without NaN value  
data_US_1 = data_US.dropna() 
data_US_1.head()
# Out:
#                     Country  Year                          FoodCode  \
# 0  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 1  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 2  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 3  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 4  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
#
#        FoodName                  AgeClass SourceAgeClass Gender  \
# 0  (All Fruits)                       All            All    All
# 1  (All Fruits)      Infants and Toddlers    0-35 months   male
# 2  (All Fruits)  Children and Adolescents      3-5 years   male
# 3  (All Fruits)  Children and Adolescents     6-14 years   male
# 4  (All Fruits)        Adults and Elderly    15-49 years   male
#
#    Number_of_consumers  Consumers_Mean  Consumers_Median  ...  \
# 0                21206        2.399773          1.222423  ...
# ...

# %%
#identfy unique food names
uniquefood_US = data_US['FoodName'].unique()
print(uniquefood_US)
# Out:
# ['(All Fruits)' '(All Nuts)' '(All Vegetables)' 'Alfalfa sprouts'
#  'Algae and prokaryotes organisms' 'Almonds' 'Amaranth grains'
#  'Aromatic herbs' 'Asparagus' 'Avocados' 'Bamboo shoots'
#  'Barley grain, pearled' 'Basil' 'Beans (dry) and similar-' 'Beetroots'
#  'Black eyed peas (dry)' 'Blond psyllium (infusion seeds, husks)'
#  'Bovine liver' 'Bovine meat, dried' 'Brazil nuts' 'Broad beans (dry)'
#  'Broccoli' 'Brussels sprouts' 'Buckwheat' 'Buffalo fresh meat'
#  'Burdock, greater or edible' 'Butternut squashes' 'Carobs' 'Carrots'
#  'Cashew nuts' 'Cassava roots' 'Cattle fresh fat tissue' 'Cauliflowers'
#  'Cavendishes' 'Celeries' 'Cereal and cereal-like flours' 'Chards'
#  'Chayote fruits' 'Chestnuts' 'Chicken fresh meat' 'Chickpeas (dry)'
#  'Chicory roots' 'Chinese broccoli' 'Chinese cabbages'
#  'Chinese water chestnut' 'Chives' 'Cinnamon bark' 'Citrons'
#  'Citrus fruits' 'Coconuts' 'Collards' 'Common millet grain'
# ...

# %%
#Identify number of uniqe food names in the data
n = len(data_US['FoodName'].unique())
  
print("No.of.unique values :", 
      n)
# Out:
# No.of.unique values : 159

# %%
#identfy unique AgeClass
uniqueAgeClass = data_US['AgeClass'].unique()
print(uniqueAgeClass)
# Out:
# ['All' 'Infants and Toddlers' 'Children and Adolescents'
#  'Adults and Elderly']

# %%
# Create All_Age dataframe from All age group in data_US data frame 
All_Age = data_US_1.loc[data['AgeClass'] == 'All', ['Country', 'Year', 'FoodCode', 'FoodName', 'SourceAgeClass', 'Gender', 'Number_of_consumers', 'Consumers_Mean', 'Consumers_Median', 'Number_of_subjects', 'Total_Mean', 'Total_Median', 'Intake_Unit']]

# %%
All_Age.head()
# Out:
#                      Country  Year                          FoodCode  \
# 0   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 13  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 14  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 21  United States of America  2010  eb31155c944a8c91ec4a53503cf50264
# 34  United States of America  2010  eb31155c944a8c91ec4a53503cf50264
#
#         FoodName SourceAgeClass  Gender  Number_of_consumers  Consumers_Mean  \
# 0   (All Fruits)            All     All                21206        2.399773
# 13  (All Fruits)            All    male                10142        2.418906
# 14  (All Fruits)            All  female                11064        2.382236
# 21    (All Nuts)            All     All                12932        0.225916
# 34    (All Nuts)            All    male                 6084        0.249923
#
#     Consumers_Median  Number_of_subjects  Total_Mean  Total_Median  \
# ...

# %%
# Create Infants_Toddlers dataframe from All age group in data_US data frame 
Infants_Toddlers = data_US_1.loc[data['AgeClass'] == 'Infants and Toddlers', ['Country', 'Year', 'FoodCode', 'FoodName', 'SourceAgeClass', 'Gender', 'Number_of_consumers', 'Consumers_Mean', 'Consumers_Median', 'Number_of_subjects', 'Total_Mean', 'Total_Median', 'Intake_Unit']]
Infants_Toddlers.head()
# Out:
#                      Country  Year                          FoodCode  \
# 1   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 7   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 15  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 22  United States of America  2010  eb31155c944a8c91ec4a53503cf50264
# 28  United States of America  2010  eb31155c944a8c91ec4a53503cf50264
#
#         FoodName SourceAgeClass  Gender  Number_of_consumers  Consumers_Mean  \
# 1   (All Fruits)    0-35 months    male                 1055        7.332808
# 7   (All Fruits)    0-35 months  female                  998        7.336989
# 15  (All Fruits)    0-35 months     All                 2053        7.334840
# 22    (All Nuts)    0-35 months    male                  458        0.397070
# 28    (All Nuts)    0-35 months  female                  383        0.361872
#
#     Consumers_Median  Number_of_subjects  Total_Mean  Total_Median  \
# ...

# %%
# Create Children_Adolescents dataframe from All age group in data_US data frame 
Children_Adolescents = data_US_1.loc[data['AgeClass'] == 'Children and Adolescents', ['Country', 'Year', 'FoodCode', 'FoodName', 'SourceAgeClass', 'Gender', 'Number_of_consumers', 'Consumers_Mean', 'Consumers_Median', 'Number_of_subjects', 'Total_Mean', 'Total_Median', 'Intake_Unit']]
Children_Adolescents.head()
# Out:
#                      Country  Year                          FoodCode  \
# 2   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 3   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 8   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 9   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 16  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
#
#         FoodName SourceAgeClass  Gender  Number_of_consumers  Consumers_Mean  \
# 2   (All Fruits)      3-5 years    male                  696        5.572249
# 3   (All Fruits)     6-14 years    male                 1950        2.378676
# 8   (All Fruits)      3-5 years  female                  649        5.373984
# 9   (All Fruits)     6-14 years  female                 1976        2.375592
# 16  (All Fruits)      3-5 years     All                 1345        5.476580
#
#     Consumers_Median  Number_of_subjects  Total_Mean  Total_Median  \
# ...

# %%
# Create Adults_Elderly dataframe from All age group in data_US data frame 
Adults_Elderly = data_US_1.loc[data['AgeClass'] == 'Adults and Elderly', ['Country', 'Year', 'FoodCode', 'FoodName', 'SourceAgeClass', 'Gender', 'Number_of_consumers', 'Consumers_Mean', 'Consumers_Median', 'Number_of_subjects', 'Total_Mean', 'Total_Median', 'Intake_Unit']]
Adults_Elderly.head()
# Out:
#                      Country  Year                          FoodCode  \
# 4   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 5   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 6   United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 10  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
# 11  United States of America  2010  e0248419de35acf267cbd31e1f7cac29
#
#         FoodName SourceAgeClass  Gender  Number_of_consumers  Consumers_Mean  \
# 4   (All Fruits)    15-49 years    male                 3489        1.141106
# 5   (All Fruits)    50-74 years    male                 2217        1.421657
# 6   (All Fruits)      >75 years    male                  735        1.559994
# 10  (All Fruits)    15-49 years  female                 4268        1.298593
# 11  (All Fruits)    50-74 years  female                 2413        1.628660
#
#     Consumers_Median  Number_of_subjects  Total_Mean  Total_Median  \
# ...
